# %%
pip install PyPDF2 pdfminer.six
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as f:
        reader = PyPDF2.PdfReader(f)
        text = ''
        for page in reader.pages:
            text += page.extract_text()
    return text

# %%
import re

def clean_text(text):
    cleaned_text = re.sub(r'\s+', ' ', text)  # Normalize whitespace
    cleaned_text = re.sub(r'[^\x00-\x7F]+', '', cleaned_text)  # Remove non-ASCII characters
    return cleaned_text

# %%
def chunk_text(text, chunk_size=500):
    words = text.split()
    chunks = [words[i:i+chunk_size] for i in range(0, len(words), chunk_size)]
    return [' '.join(chunk) for chunk in chunks]

# %%
pip install sentence-transformers
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sentence_transformers import SentenceTransformer

def generate_embeddings(chunks):
    model = SentenceTransformer('all-MiniLM-L6-v2')
    embeddings = model.encode(chunks)
    return embeddings

# %%
pip install faiss-cpu
# Out:
# ...
#    ---------------------------------------- 0.0/13.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/13.8 MB 409.6 kB/s eta 0:00:34
#    ---------------------------------------- 0.1/13.8 MB 409.6 kB/s eta 0:00:34
#    ---------------------------------------- 0.1/13.8 MB 504.4 kB/s eta 0:00:28
#    ---------------------------------------- 0.1/13.8 MB 462.0 kB/s eta 0:00:30
#     --------------------------------------- 0.2/13.8 MB 689.6 kB/s eta 0:00:20
#     --------------------------------------- 0.2/13.8 MB 689.6 kB/s eta 0:00:20
#     --------------------------------------- 0.3/13.8 MB 703.7 kB/s eta 0:00:20
#     --------------------------------------- 0.3/13.8 MB 752.2 kB/s eta 0:00:18
#    - -------------------------------------- 0.4/13.8 MB 774.0 kB/s eta 0:00:18
# ...

# %%
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer

# Define the embedding dimension (384 for the all-MiniLM-L6-v2 model)
embedding_dim = 384

# Initialize Sentence Transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Example text chunks
chunks = ["This is a sample sentence.", "Another example of a sentence for testing."]

# Generate embeddings for the chunks
embeddings = model.encode(chunks)

# Initialize FAISS index with the correct embedding dimension
index = faiss.IndexFlatL2(embedding_dim)

# Add embeddings to the FAISS index
index.add(np.array(embeddings))

# Query handling function to retrieve relevant chunks
def retrieve_relevant_chunks(query, index, model):
    query_embedding = model.encode([query])
    _, indices = index.search(query_embedding, k=5)  # Retrieve top 5 results
    return [chunks[i] for i in indices[0]]

# Example usage of the function
query = "What is an example sentence?"
relevant_chunks = retrieve_relevant_chunks(query, index, model)
print(relevant_chunks)
# Out:
# ['This is a sample sentence.', 'Another example of a sentence for testing.', 'Another example of a sentence for testing.', 'Another example of a sentence for testing.', 'Another example of a sentence for testing.']

# %%
pip install cohere
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cohere_api_key = oGY911s4SFviCFwKqUpKBI7IEEc1ZVQ41SzNiwWH

# %%
import cohere

# Initialize Cohere API client
cohere_client = cohere.Client('oGY911s4SFviCFwKqUpKBI7IEEc1ZVQ41SzNiwWH')  # Replace with your Cohere API key

def generate_answer_with_cohere(question, context):
    # Construct the prompt
    prompt = f"Question: {question}\nContext: {context}\nAnswer:"

    # Generate an answer using Cohere's language model
    response = cohere_client.generate(
        prompt=prompt,
        max_tokens=150,
        temperature=0.7  # Adjust the temperature to control randomness
    )

    # Return the generated answer
    return response.generations[0].text.strip()

# Example usage
question = "What is the main contribution of the paper?"
context = "The paper introduces a new architecture that improves efficiency by 25% while maintaining performance on benchmark datasets."

answer = generate_answer_with_cohere(question, context)
print(answer)
# Out:
# C:\Users\surya\anaconda3\Lib\site-packages\pydantic\_internal\_fields.py:172: UserWarning: Field name "json" in "MonitoringDatasetFormat" shadows an attribute in parent "Base"
#   warnings.warn(
# sagemaker.config INFO - Not applying SDK defaults from location: C:\ProgramData\sagemaker\sagemaker\config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: C:\Users\surya\AppData\Local\sagemaker\sagemaker\config.yaml
# [01/30/25 11:33:03] INFO     HTTP Request: POST https://api.cohere.com/v1/generate "HTTP/1.1 200    ]8;id=567599;file://C:\Users\surya\anaconda3\Lib\site-packages\httpx\_client.py\_client.py]8;;\:]8;id=455543;file://C:\Users\surya\anaconda3\Lib\site-packages\httpx\_client.py#1038\1038]8;;\
#                              OK"
# ...

# %%
import streamlit as st
import pdfplumber
import re
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer
import cohere  # Import Cohere library

# Initialize the embedding model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Initialize the Cohere client
co = cohere.Client("oGY911s4SFviCFwKqUpKBI7IEEc1ZVQ41SzNiwWH")  # Replace with your Cohere API key

# Function to extract text from PDF
def extract_text_from_pdf(uploaded_file):
    text = ""
    with pdfplumber.open(uploaded_file) as pdf:
        for page in pdf.pages:
            text += page.extract_text()
    return text

# Function to clean text
def clean_text(text):
    text = re.sub(r'\s+', ' ', text)  # Remove extra spaces
    text = re.sub(r'[^\x00-\x7F]+', '', text)  # Remove non-ASCII characters
    return text

# Function to chunk text
def chunk_text(text, chunk_size=200):  # Smaller chunk size
    words = text.split()
    chunks = [' '.join(words[i:i + chunk_size]) for i in range(0, len(words), chunk_size)]
    return chunks

# Function to retrieve relevant chunks
def retrieve_relevant_chunks(query, top_k=3):  # Fewer chunks
    query_embedding = model.encode([query])
    distances, indices = index.search(query_embedding, top_k)
    relevant_chunks = [chunks[i] for i in indices[0]]
    return relevant_chunks

# Function to truncate context
def truncate_context(context, max_tokens=3000):
    words = context.split()
    truncated_context = " ".join(words[:max_tokens])
    return truncated_context

# Function to generate answers using Cohere
def generate_answer(query, relevant_chunks):
    context = "\n".join(relevant_chunks)
    truncated_context = truncate_context(context)  # Truncate the context
    prompt = f"Query: {query}\nContext: {truncated_context}\nAnswer:"
    
    # Generate response using Cohere
    response = co.generate(
        model="command",  # Use Cohere's "command" model
        prompt=prompt,
        max_tokens=200,  # Adjust as needed
        temperature=0.7,  # Adjust for creativity
        stop_sequences=["\n"],  # Stop generation at newlines
        truncate="END"  # Enable prompt truncation
    )
    
    return response.generations[0].text

# Streamlit app
st.title("RAG Application for Research Papers")

uploaded_file = st.file_uploader("Upload a research paper (PDF)", type="pdf")
if uploaded_file:
    # Extract text from the uploaded PDF
    extracted_text = extract_text_from_pdf(uploaded_file)
    
    # Clean and chunk the text
    chunks = chunk_text(clean_text(extracted_text))
    
    # Generate embeddings for the chunks
    embeddings = model.encode(chunks)
    
    # Create a FAISS index and add embeddings
    dimension = embeddings.shape[1]
    index = faiss.IndexFlatL2(dimension)
    index.add(np.array(embeddings))

    # Accept user query
    query = st.text_input("Enter your query:")
    if query:
        # Retrieve relevant chunks
        relevant_chunks = retrieve_relevant_chunks(query)
        
        # Generate an answer using Cohere
        answer = generate_answer(query, relevant_chunks)
        
        # Display the answer and relevant sections
        st.write("Answer:", answer)
        st.write("Relevant Sections:")
        for chunk in relevant_chunks:
            st.write(chunk)
